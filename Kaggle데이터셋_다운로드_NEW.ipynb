# %%
# !pip install kaggle==1.8
# Out:
# Requirement already satisfied: kaggle==1.8 in c:\users\user\miniconda3\envs\ds\lib\site-packages (1.8.0)
# Requirement already satisfied: black>=24.10.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle==1.8) (26.1.0)
# Requirement already satisfied: bleach in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle==1.8) (6.3.0)
# Requirement already satisfied: kagglesdk in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle==1.8) (0.1.15)
# Requirement already satisfied: mypy>=1.15.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle==1.8) (1.19.1)
# Requirement already satisfied: protobuf in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle==1.8) (6.33.4)
# Requirement already satisfied: python-slugify in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle==1.8) (8.0.4)
# Requirement already satisfied: requests in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle==1.8) (2.32.5)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle==1.8) (80.9.0)
# Requirement already satisfied: six>=1.10 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle==1.8) (1.17.0)
# Requirement already satisfied: tqdm in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle==1.8) (4.67.1)
# Requirement already satisfied: types-requests in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle==1.8) (2.32.4.20260107)
# Requirement already satisfied: types-tqdm in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle==1.8) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle==1.8) (2.6.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from black>=24.10.0->kaggle==1.8) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from black>=24.10.0->kaggle==1.8) (1.1.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from black>=24.10.0->kaggle==1.8) (25.0)
# Requirement already satisfied: pathspec>=1.0.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from black>=24.10.0->kaggle==1.8) (1.0.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from black>=24.10.0->kaggle==1.8) (4.5.1)
# Requirement already satisfied: pytokens>=0.3.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from black>=24.10.0->kaggle==1.8) (0.4.0)
# Requirement already satisfied: colorama in c:\users\user\miniconda3\envs\ds\lib\site-packages (from click>=8.0.0->black>=24.10.0->kaggle==1.8) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.6.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from mypy>=1.15.0->kaggle==1.8) (4.15.0)
# Requirement already satisfied: librt>=0.6.2 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from mypy>=1.15.0->kaggle==1.8) (0.7.8)
# Requirement already satisfied: webencodings in c:\users\user\miniconda3\envs\ds\lib\site-packages (from bleach->kaggle==1.8) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from python-slugify->kaggle==1.8) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from requests->kaggle==1.8) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from requests->kaggle==1.8) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from requests->kaggle==1.8) (2026.1.4)

# %% [markdown]
# ## **Runtime** -> **Restart Session** 후 다음 내용 실행

# %%
import os
# kaggle.json 파일을 메모장으로 열어서 값을 확인 후 아래에 입력하세요
os.environ['KAGGLE_USERNAME'] = 'charles1105'
os.environ['KAGGLE_KEY'] = '332f99ba052ffdb35114ac1df063fc8a'
import kaggle

# %%
import kaggle
print(kaggle.__version__)
# Out:
# 1.8.0

# %%
# python-dotenv 설치
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\user\miniconda3\envs\ds\lib\site-packages (1.2.1)

# %%
# load_dotenv()로 .env 내용 가져오기
from dotenv import load_dotenv
# .env 파일 활성화
load_dotenv()
# Out:
# True

# %%
# # Colab 시크릿에서 Kaggle 토큰 가져오기
# from google.colab import userdata
# import os

# # 방법 1: 환경변수로 설정 (Kaggle 1.8+ 단일 토큰 방식)
# os.environ['KAGGLE_API_TOKEN'] = userdata.get('KAGGLE_KEY')

# Colab 시크릿에서 Kaggle 토큰 가져오기
#from google.colab import userdata
import os

# 환경 변수 읽어오기
kaggle_username = os.getenv('KAGGLE_USERNAME')
kaggle_key = os.getenv('KAGGLE_KEY')
# 확인 (보안을 위해 실제 출력 시 주의하세요)
print(f"Kaggle Username: {kaggle_username}")
print(f"Kaggle key: {kaggle_key}")
# Out:
# Kaggle Username: charles1105
# Kaggle key: 332f99ba052ffdb35114ac1df063fc8a

# %%
# !kaggle competitions list
# Out:
# ref                                                                              deadline             category          reward  teamCount  userHasEntered
# -------------------------------------------------------------------------------  -------------------  ---------  -------------  ---------  --------------
# https://www.kaggle.com/competitions/ai-mathematical-olympiad-progress-prize-3    2026-04-15 23:59:00  Featured   2,207,152 Usd       1505           False
# https://www.kaggle.com/competitions/passenger-screening-algorithm-challenge      2017-12-15 23:59:00  Featured   1,500,000 Usd        518           False
# https://www.kaggle.com/competitions/zillow-prize-1                               2018-01-10 15:59:00  Featured   1,200,000 Usd       3770           False
# https://www.kaggle.com/competitions/data-science-bowl-2017                       2017-04-12 23:59:00  Featured   1,000,000 Usd       1972           False
# https://www.kaggle.com/competitions/vesuvius-challenge-ink-detection             2023-06-14 23:59:00  Featured   1,000,000 Usd       1249           False
# https://www.kaggle.com/competitions/gemini-3                                     2025-12-12 23:59:00  Featured     500,000 Usd       4101           False
# https://www.kaggle.com/competitions/openai-gpt-oss-20b-red-teaming               2025-08-26 23:59:00  Featured     500,000 Usd        606           False
# https://www.kaggle.com/competitions/openai-to-z-challenge                        2025-06-29 23:59:00  Featured     500,000 Usd        225           False
# https://www.kaggle.com/competitions/llm-prompt-recovery                          2024-04-16 23:59:00  Featured     200,000 Usd       2175           False
# https://www.kaggle.com/competitions/asl-fingerspelling                           2023-08-24 23:59:00  Research     200,000 Usd       1314           False
# https://www.kaggle.com/competitions/vesuvius-challenge-surface-detection         2026-02-13 23:59:00  Research     200,000 Usd        705           False
# https://www.kaggle.com/competitions/second-annual-data-science-bowl              2016-03-14 23:59:00  Featured     200,000 Usd        192           False
# https://www.kaggle.com/competitions/datasciencebowl                              2015-03-16 23:59:00  Featured     175,000 Usd       1049           False
# https://www.kaggle.com/competitions/data-science-bowl-2019                       2020-01-22 23:59:00  Featured     160,000 Usd       3493           False
# https://www.kaggle.com/competitions/feedback-prize-2021                          2022-03-15 23:59:00  Featured     160,000 Usd       2058           False
# https://www.kaggle.com/competitions/the-nature-conservancy-fisheries-monitoring  2017-04-12 23:59:00  Featured     150,000 Usd       2293           False
# https://www.kaggle.com/competitions/tensorflow-great-barrier-reef                2022-02-14 23:59:00  Research     150,000 Usd       2025           False
# https://www.kaggle.com/competitions/AI4Code                                      2022-11-10 23:59:00  Featured     150,000 Usd       1135           False
# https://www.kaggle.com/competitions/google-gemma-3n-hackathon                    2025-08-06 23:59:00  Featured     150,000 Usd        605           False
# https://www.kaggle.com/competitions/gemma-language-tuning                        2025-01-15 00:59:00  Analytics    150,000 Usd          0           False

# %%
# !kaggle competitions download -c titanic
# Out:
# titanic.zip: Skipping, found more recently modified local copy (use --force to force download)
